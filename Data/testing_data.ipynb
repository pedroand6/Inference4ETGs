# %%
import bagpipes as pipes
import numpy as np
import illustris_python as il

dblplaw = {}
dblplaw["massformed"] = 1e10
dblplaw["metallicity"] = -0.4

dblplaw["alpha"] = 30
dblplaw["beta"] = 0.5
dblplaw["tau"] = 12

dust = {}
dust["type"] = "Calzetti"
dust["Av"] = 0.2
dust["eta"] = 3

model_components = {}
model_components["dblplaw"] = dblplaw
model_components["dust"] = dust
model_components["redshift"] = 0 # redshift observado
model_components["t_bc"] = 0.01 #
model_components["veldisp"] = 350 # dispersao de velocidade em km/s

filt_list = np.loadtxt("splus-filters/splus_filters.txt", dtype="str")

model = pipes.model_galaxy(model_components, filt_list=filt_list)
